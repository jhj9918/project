# %%
from colorthief import ColorThief
import matplotlib.pyplot as plt
import colorsys
import cv2
import pandas as pd

# %%
# ['jeju_35','jeonnam_138','jeju_163','gyeongbuk_260','gangwon_237','gyeongnam_103']
color_df = pd.DataFrame(columns=['jeju_35','jeonnam_138','jeju_163','gyeongbuk_260','gangwon_237','gyeongnam_103'])

# %%
# index=['knn','cos', 'kmeans'],
color_df=color_df.append({'jeju_35': 10,'jeonnam_138': 10,'jeju_163': 9,'gyeongbuk_260': 9,'gangwon_237': 9,'gyeongnam_103': 9, 'model':'KNN'},ignore_index=True)
color_df=color_df.append({'jeju_35': 10,'jeonnam_138': 9,'jeju_163': 9,'gyeongbuk_260': 7,'gangwon_237': 10,'gyeongnam_103': 9,'model':'COS'},ignore_index=True)
color_df=color_df.append({'jeju_35': 10,'jeonnam_138': 10,'jeju_163': 9,'gyeongbuk_260': 7,'gangwon_237': 10,'gyeongnam_103': 8, 'model':'KNEANS'},ignore_index=True)
color_df = color_df.set_index('model')
color_df['sum'] = color_df.sum(axis=1)
color_df['mean'] = color_df.iloc[:,:-1].mean(axis=1)
# Out:
# /var/folders/_w/hwmlhxls3n5369nntphfh0s80000gn/T/ipykernel_1169/2112836218.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   color_df=color_df.append({'jeju_35': 10,'jeonnam_138': 10,'jeju_163': 9,'gyeongbuk_260': 9,'gangwon_237': 9,'gyeongnam_103': 9, 'model':'KNN'},ignore_index=True)
# /var/folders/_w/hwmlhxls3n5369nntphfh0s80000gn/T/ipykernel_1169/2112836218.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   color_df=color_df.append({'jeju_35': 10,'jeonnam_138': 9,'jeju_163': 9,'gyeongbuk_260': 7,'gangwon_237': 10,'gyeongnam_103': 9,'model':'COS'},ignore_index=True)
# /var/folders/_w/hwmlhxls3n5369nntphfh0s80000gn/T/ipykernel_1169/2112836218.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
color_df.to_csv('in&out&color_total_score.csv')

# %%
ct = ColorThief('/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/gyeongbuk_284.jpg')
dominant_cor = ct.get_color()

plt.imshow([[dominant_cor]])
plt.show()

# %%
ct.get_palette()
# Out:
# [(88, 92, 72),
#  (206, 199, 181),
#  (46, 42, 43),
#  (148, 148, 135),
#  (146, 149, 103),
#  (166, 183, 122),
#  (33, 34, 33),
#  (128, 143, 91),
#  (169, 166, 177)]

# %%
len(ct.get_palette())
# Out:
# 9

# %%
dominant_cor
# Out:
# (95, 98, 77)

# %%
ct = ColorThief('/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/gyeongbuk_284.jpg')
palette = ct.get_palette()

img = cv2.imread('/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/gyeongbuk_284.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.subplot(121)
plt.imshow(img)

plt.subplot(122)
plt.imshow([[palette[i] for i in range(len(palette))]])
plt.show()

# %%
df = pd.read_csv('/Users/hanjun/Desktop/python/비타민/추천시스템/recommend_result.csv')

# %%
df.head()
# Out:
#       base_image                                          image_url  \
# 0  gyeongnam_203  https://a0.muscache.com/im/pictures/e6a42adb-d...
# 1  gyeongnam_203  https://a0.muscache.com/im/pictures/f8c4979c-8...
# 2  gyeongnam_203  https://a0.muscache.com/im/pictures/0016dbef-a...
# 3  gyeongnam_203  https://a0.muscache.com/im/pictures/788a847b-0...
# 4  gyeongnam_203  https://a0.muscache.com/im/pictures/cffc42d0-3...
#
#                                 숙소이름  \
# 0        Dongbu-myeon, Geoje-si의 개인실
# 1  Ongryong-myeon, Gwangyang-si의 개인실
# 2                 Jangheung-gun의 개인실
# 3                           안동시의 개인실
# 4                        Buk-gu의 개인실
#
#                                                 한줄소개  \
# 0  거제 통영 가족여행 최적 YK Happy House. 스페인풍 바다전망 2층 개인실...
# 1                                  돌과 흙으로 지어진 토궁 세번째
# 2                                               아름드리
# 3                   사랑방 [안동 풍송재] 방1, 화장실 (하회마을10분거리)
# 4                                              이야기별밤
#
# ...

# %%
img_list = df[df['base_image']=='jeju_35']['image_index'].to_list()
img_list
# Out:
# ['jeju_166', 'gangwon_25', 'gangwon_194', 'gyeongnam_201', 'jeonnam_290']

# %%
ct1 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/jeju_35.jpg')
palette1 = ct1.get_palette(color_count=3)

rimg = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/jeju_35.jpg')
rimg = cv2.cvtColor(rimg, cv2.COLOR_BGR2RGB)

for i in img_list:
    
    # 추천 이미지
    ct2 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    palette2 = ct2.get_palette(color_count=3)
    
    img = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.subplot(141)
    plt.axis('off')
    plt.imshow(rimg)

    plt.subplot(142)
    plt.axis('off')

    plt.imshow([[palette1[i] for i in range(3)]])

    plt.subplot(143)
    plt.axis('off')
    plt.imshow(img)

    plt.subplot(144)
    plt.axis('off')
    plt.imshow([[palette2[i] for i in range(3)]])
    
    plt.show()

# %%
img_list = df[df['base_image']=='jeonnam_138']['image_index'].to_list()
img_list

ct1 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/jeonnam_138.jpg')
palette1 = ct1.get_palette(color_count=3)

rimg = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/jeonnam_138.jpg')
rimg = cv2.cvtColor(rimg, cv2.COLOR_BGR2RGB)

for i in img_list:
    
    # 추천 이미지
    ct2 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    palette2 = ct2.get_palette(color_count=3)
    
    img = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.subplot(141)
    plt.axis('off')
    plt.imshow(rimg)

    plt.subplot(142)
    plt.axis('off')

    plt.imshow([[palette1[i] for i in range(3)]])

    plt.subplot(143)
    plt.axis('off')
    plt.imshow(img)

    plt.subplot(144)
    plt.axis('off')
    plt.imshow([[palette2[i] for i in range(3)]])
    
    plt.show()

# %%
img_list = df[df['base_image']=='jeju_287']['image_index'].to_list()
img_list

ct1 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/jeju_287.jpg')
palette1 = ct1.get_palette(color_count=3)

rimg = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/jeju_287.jpg')
rimg = cv2.cvtColor(rimg, cv2.COLOR_BGR2RGB)

for i in img_list:
    
    # 추천 이미지
    ct2 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    palette2 = ct2.get_palette(color_count=3)
    
    img = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.subplot(141)
    plt.axis('off')
    plt.imshow(rimg)

    plt.subplot(142)
    plt.axis('off')

    plt.imshow([[palette1[i] for i in range(3)]])

    plt.subplot(143)
    plt.axis('off')
    plt.imshow(img)

    plt.subplot(144)
    plt.axis('off')
    plt.imshow([[palette2[i] for i in range(3)]])
    
    plt.show()

# %%
img_list = df[df['base_image']=='jeju_163']['image_index'].to_list()
img_list

ct1 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/jeju_163.jpg')
palette1 = ct1.get_palette(color_count=3)

rimg = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/jeju_163.jpg')
rimg = cv2.cvtColor(rimg, cv2.COLOR_BGR2RGB)

for i in img_list:
    
    # 추천 이미지
    ct2 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    palette2 = ct2.get_palette(color_count=3)
    
    img = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.subplot(141)
    plt.axis('off')
    plt.imshow(rimg)

    plt.subplot(142)
    plt.axis('off')

    plt.imshow([[palette1[i] for i in range(3)]])

    plt.subplot(143)
    plt.axis('off')
    plt.imshow(img)

    plt.subplot(144)
    plt.axis('off')
    plt.imshow([[palette2[i] for i in range(3)]])
    
    plt.show()

# %%
img_list = df[df['base_image']=='gyeongbuk_260']['image_index'].to_list()
img_list

ct1 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/gyeongbuk_260.jpg')
palette1 = ct1.get_palette(color_count=3)

rimg = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/gyeongbuk_260.jpg')
rimg = cv2.cvtColor(rimg, cv2.COLOR_BGR2RGB)

for i in img_list:
    
    # 추천 이미지
    ct2 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    palette2 = ct2.get_palette(color_count=3)
    
    img = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.subplot(141)
    plt.axis('off')
    plt.imshow(rimg)

    plt.subplot(142)
    plt.axis('off')

    plt.imshow([[palette1[i] for i in range(3)]])

    plt.subplot(143)
    plt.axis('off')
    plt.imshow(img)

    plt.subplot(144)
    plt.axis('off')
    plt.imshow([[palette2[i] for i in range(3)]])
    
    plt.show()

# %%
img_list = df[df['base_image']=='gangwon_237']['image_index'].to_list()
img_list

ct1 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/gangwon_237.jpg')
palette1 = ct1.get_palette(color_count=3)

rimg = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/gangwon_237.jpg')
rimg = cv2.cvtColor(rimg, cv2.COLOR_BGR2RGB)

for i in img_list:
    
    # 추천 이미지
    ct2 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    palette2 = ct2.get_palette(color_count=3)
    
    img = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.subplot(141)
    plt.axis('off')
    plt.imshow(rimg)

    plt.subplot(142)
    plt.axis('off')

    plt.imshow([[palette1[i] for i in range(3)]])

    plt.subplot(143)
    plt.axis('off')
    plt.imshow(img)

    plt.subplot(144)
    plt.axis('off')
    plt.imshow([[palette2[i] for i in range(3)]])
    
    plt.show()

# %% [markdown]
# ## 코사인 유사도

# %%
a = ['jeju_35', 'gangwon_25', 'gangwon_194', 'jeonnam_290', 'gyeongnam_293', 'gyeongnam_201', 'gyeongbuk_240', 'jeju_166', 'jeju_190', 'gangwon_177', 'gyeongnam_207', 'gyeongnam_213', 'gyeongnam_123', 'jeonnam_72', 'jeonnam_14']
b = ['jeonnam_138', 'jeonnam_295', 'jeonnam_139', 'gyeongnam_199', 'gyeongbuk_242', 'jeonnam_287', 'jeonnam_43', 'gangwon_265', 'jeonnam_292', 'gangwon_193', 'jeju_102', 'gangwon_238', 'jeonnam_261', 'jeonnam_78', 'gangwon_84']
c = ['jeju_163', 'jeju_78', 'jeonnam_87', 'gyeongbuk_195', 'jeonnam_137', 'jeonnam_121', 'jeonnam_285', 'gyeongnam_12', 'jeonnam_26', 'jeonnam_51', 'gyeongnam_265', 'jeju_38', 'gyeongbuk_1', 'gyeongnam_197', 'gyeongnam_217']
d = ['gyeongbuk_260', 'gyeongbuk_60', 'gyeongbuk_235', 'gyeongnam_93', 'gangwon_30', 'jeonnam_178', 'jeonnam_152', 'jeju_298', 'gyeongnam_203', 'gyeongnam_195', 'gyeongnam_186', 'jeonnam_31', 'gyeongbuk_134', 'gyeongbuk_262', 'jeju_91']
e = ['gangwon_237', 'gangwon_86', 'jeonnam_295', 'gangwon_155', 'gangwon_63', 'gyeongbuk_242', 'gyeongnam_178', 'gangwon_74', 'gangwon_132', 'gyeongnam_294', 'gangwon_189', 'jeonnam_139', 'gangwon_265', 'gangwon_128', 'gyeongnam_156']
f = ['gyeongnam_103', 'jeonnam_31', 'gyeongbuk_134', 'gangwon_45', 'gyeongbuk_107', 'gyeongbuk_194', 'jeju_60', 'jeonnam_296', 'gangwon_275', 'jeju_160', 'gyeongnam_186', 'jeonnam_178', 'jeju_286', 'gyeongbuk_162', 'jeju_55']

# %%
ct1 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{a[0]}.jpg')
palette1 = ct1.get_palette(color_count=3)

rimg = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{a[0]}.jpg')
rimg = cv2.cvtColor(rimg, cv2.COLOR_BGR2RGB)

for i in a[1:6]:
    
    # 추천 이미지
    ct2 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    palette2 = ct2.get_palette(color_count=3)
    
    img = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.subplot(141)
    plt.axis('off')
    plt.imshow(rimg)

    plt.subplot(142)
    plt.axis('off')

    plt.imshow([[palette1[i] for i in range(3)]])

    plt.subplot(143)
    plt.axis('off')
    plt.imshow(img)

    plt.subplot(144)
    plt.axis('off')
    plt.imshow([[palette2[i] for i in range(3)]])
    
    plt.show()

# %%
ct1 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{b[0]}.jpg')
palette1 = ct1.get_palette(color_count=3)

rimg = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{b[0]}.jpg')
rimg = cv2.cvtColor(rimg, cv2.COLOR_BGR2RGB)

for i in b[1:6]:
    
    # 추천 이미지
    ct2 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    palette2 = ct2.get_palette(color_count=3)
    
    img = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.subplot(141)
    plt.axis('off')
    plt.imshow(rimg)

    plt.subplot(142)
    plt.axis('off')

    plt.imshow([[palette1[i] for i in range(3)]])

    plt.subplot(143)
    plt.axis('off')
    plt.imshow(img)

    plt.subplot(144)
    plt.axis('off')
    plt.imshow([[palette2[i] for i in range(3)]])
    
    plt.show()

# %%
ct1 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{c[0]}.jpg')
palette1 = ct1.get_palette(color_count=3)

rimg = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{c[0]}.jpg')
rimg = cv2.cvtColor(rimg, cv2.COLOR_BGR2RGB)

for i in c[1:6]:
    
    # 추천 이미지
    ct2 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    palette2 = ct2.get_palette(color_count=3)
    
    img = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.subplot(141)
    plt.axis('off')
    plt.imshow(rimg)

    plt.subplot(142)
    plt.axis('off')

    plt.imshow([[palette1[i] for i in range(3)]])

    plt.subplot(143)
    plt.axis('off')
    plt.imshow(img)

    plt.subplot(144)
    plt.axis('off')
    plt.imshow([[palette2[i] for i in range(3)]])
    
    plt.show()

# %% [markdown]
# 3점

# %%
ct1 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{e[0]}.jpg')
palette1 = ct1.get_palette(color_count=3)

rimg = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{e[0]}.jpg')
rimg = cv2.cvtColor(rimg, cv2.COLOR_BGR2RGB)

for i in e[1:6]:
    
    # 추천 이미지
    ct2 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    palette2 = ct2.get_palette(color_count=3)
    
    img = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.subplot(141)
    plt.axis('off')
    plt.imshow(rimg)

    plt.subplot(142)
    plt.axis('off')

    plt.imshow([[palette1[i] for i in range(3)]])

    plt.subplot(143)
    plt.axis('off')
    plt.imshow(img)

    plt.subplot(144)
    plt.axis('off')
    plt.imshow([[palette2[i] for i in range(3)]])
    
    plt.show()

# %%
ct1 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{f[0]}.jpg')
palette1 = ct1.get_palette(color_count=3)

rimg = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{f[0]}.jpg')
rimg = cv2.cvtColor(rimg, cv2.COLOR_BGR2RGB)

for i in f[1:6]:
    
    # 추천 이미지
    ct2 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    palette2 = ct2.get_palette(color_count=3)
    
    img = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.subplot(141)
    plt.axis('off')
    plt.imshow(rimg)

    plt.subplot(142)
    plt.axis('off')

    plt.imshow([[palette1[i] for i in range(3)]])

    plt.subplot(143)
    plt.axis('off')
    plt.imshow(img)

    plt.subplot(144)
    plt.axis('off')
    plt.imshow([[palette2[i] for i in range(3)]])
    
    plt.show()

# %% [markdown]
# 4점

# %% [markdown]
# ## kmeans

# %%
# ['jeju_35','jeonnam_138','jeju_163','gyeongbuk_260','gangwon_237','gyeongnam_103']
a=['jeju_35','gangwon_25','gangwon_194','jeonnam_290','gyeongnam_207','gyeongbuk_240']
b=['jeonnam_138','gyeongnam_199','gyeongbuk_242','jeonnam_43','gangwon_238','gangwon_265']
c=['jeju_163','jeju_78','jeonnam_87','gyeongbuk_195','jeonnam_137','jeonnam_121']
d=['gyeongbuk_260','gyeongbuk_60','gyeongnam_93','gangwon_30','jeonnam_152','jeonnam_178']
e=['gangwon_237','jeonnam_295','gangwon_86','gangwon_63','gyeongnam_178','gangwon_74']
f=['gyeongnam_103','jeonnam_31','gyeongbuk_134','gyeongbuk_107','gangwon_45','jeju_60']

# %%
ct1 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{a[0]}.jpg')
palette1 = ct1.get_palette(color_count=3)

rimg = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{a[0]}.jpg')
rimg = cv2.cvtColor(rimg, cv2.COLOR_BGR2RGB)

for i in a[1:6]:
    
    # 추천 이미지
    ct2 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    palette2 = ct2.get_palette(color_count=3)
    
    img = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.subplot(141)
    plt.axis('off')
    plt.imshow(rimg)

    plt.subplot(142)
    plt.axis('off')

    plt.imshow([[palette1[i] for i in range(3)]])

    plt.subplot(143)
    plt.axis('off')
    plt.imshow(img)

    plt.subplot(144)
    plt.axis('off')
    plt.imshow([[palette2[i] for i in range(3)]])
    
    plt.show()

# %% [markdown]
# 5점

# %%
ct1 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{b[0]}.jpg')
palette1 = ct1.get_palette(color_count=3)

rimg = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{b[0]}.jpg')
rimg = cv2.cvtColor(rimg, cv2.COLOR_BGR2RGB)

for i in b[1:6]:
    
    # 추천 이미지
    ct2 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    palette2 = ct2.get_palette(color_count=3)
    
    img = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.subplot(141)
    plt.axis('off')
    plt.imshow(rimg)

    plt.subplot(142)
    plt.axis('off')

    plt.imshow([[palette1[i] for i in range(3)]])

    plt.subplot(143)
    plt.axis('off')
    plt.imshow(img)

    plt.subplot(144)
    plt.axis('off')
    plt.imshow([[palette2[i] for i in range(3)]])
    
    plt.show()

# %% [markdown]
# 5

# %%
ct1 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{c[0]}.jpg')
palette1 = ct1.get_palette(color_count=3)

rimg = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{c[0]}.jpg')
rimg = cv2.cvtColor(rimg, cv2.COLOR_BGR2RGB)

for i in c[1:6]:
    
    # 추천 이미지
    ct2 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    palette2 = ct2.get_palette(color_count=3)
    
    img = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.subplot(141)
    plt.axis('off')
    plt.imshow(rimg)

    plt.subplot(142)
    plt.axis('off')

    plt.imshow([[palette1[i] for i in range(3)]])

    plt.subplot(143)
    plt.axis('off')
    plt.imshow(img)

    plt.subplot(144)
    plt.axis('off')
    plt.imshow([[palette2[i] for i in range(3)]])
    
    plt.show()

# %% [markdown]
# 2

# %%
ct1 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{e[0]}.jpg')
palette1 = ct1.get_palette(color_count=3)

rimg = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{e[0]}.jpg')
rimg = cv2.cvtColor(rimg, cv2.COLOR_BGR2RGB)

for i in e[1:6]:
    
    # 추천 이미지
    ct2 = ColorThief(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    palette2 = ct2.get_palette(color_count=3)
    
    img = cv2.imread(f'/Users/hanjun/Desktop/python/비타민/추천시스템/중복처리완료_데이터/{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.subplot(141)
    plt.axis('off')
    plt.imshow(rimg)

    plt.subplot(142)
    plt.axis('off')

    plt.imshow([[palette1[i] for i in range(3)]])

    plt.subplot(143)
    plt.axis('off')
    plt.imshow(img)

    plt.subplot(144)
    plt.axis('off')
    plt.imshow([[palette2[i] for i in range(3)]])
    
    plt.show()
